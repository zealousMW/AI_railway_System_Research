# %%
pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ultralytics import YOLO, RTDETR

# %%
model = RTDETR('rtdetr-l.pt')

# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# False

# %%
results = model("sample.mp4", save=True, conf=0.4)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/1126) C:\Users\admin\Desktop\college_work\sih\sample.mp4: 640x640 1 62, 148.0ms
# video 1/1 (2/1126) C:\Users\admin\Desktop\college_work\sih\sample.mp4: 640x640 1 62, 34.0ms
# video 1/1 (3/1126) C:\Users\admin\Desktop\college_work\sih\sample.mp4: 640x640 1 62, 33.0ms
# video 1/1 (4/1126) C:\Users\admin\Desktop\college_work\sih\sample.mp4: 640x640 1 62, 34.0ms
# ...

# %%
# !nvidia-smi
# Out:
# Unable to determine the device handle for GPU0000:01:00.0: GPU is lost.  Reboot the system to recover this GPU

# %%
# !yolo task=detect mode=predict model=yolov8x.pt source=sample.mp4 conf=0.5 save=true save_crop=true hide_labels=true hide_conf=true
# Out:
# WARNING  'hide_labels' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'show_labels' instead.
# WARNING  'hide_conf' is deprecated and will be removed in 'ultralytics 8.2' in the future. Please use 'show_conf' instead.
# Ultralytics YOLOv8.0.188  Python-3.11.4 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# YOLOv8x summary (fused): 268 layers, 68200608 parameters, 0 gradients
#
# video 1/1 (1/1126) C:\Users\admin\Desktop\college_ work\smart indian hackthon\sample.mp4: 384x640 (no detections), 98.0ms
# video 1/1 (2/1126) C:\Users\admin\Desktop\college_ work\smart indian hackthon\sample.mp4: 384x640 (no detections), 30.5ms
# video 1/1 (3/1126) C:\Users\admin\Desktop\college_ work\smart indian hackthon\sample.mp4: 384x640 (no detections), 29.0ms
# video 1/1 (4/1126) C:\Users\admin\Desktop\college_ work\smart indian hackthon\sample.mp4: 384x640 (no detections), 29.1ms
# ...

# %%
# !yolo task=detect mode=predict model=yolov8n.pt source=11.jpg conf=0.5 save=true

# %%
from ultralytics import RTDETR

# %%
model = RTDETR('best7.pt')

# %%
import cv2

# %%
result = model.predict(source="0", show=True)
print(result)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 result
#
# NameError: name 'result' is not defined

# %%
# !yolo task=detect mode=predict model=best5.pt source=sample2.mp4 conf=0.25 save=true save_crop=true
# Out:
# Ultralytics YOLOv8.0.188  Python-3.11.4 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# rt-detr-l summary: 498 layers, 31985795 parameters, 0 gradients
#
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\admin\AppData\Local\Programs\Python\Python311\Scripts\yolo.exe\__main__.py", line 7, in <module>
#   File "C:\Users\admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\cfg\__init__.py", line 445, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\engine\model.py", line 235, in predict
#     return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
results = model.train(data='coco8.yaml', epochs=100, imgsz=640)

# %%
import cv2

# %%
cap = cv2.VideoCapture(0)

# %%
while True:
    ret, frame = cap.read()  # Read a frame from the camera


    # Perform object detection on the frame
    results = model(frame)

    # Post-process the detection results (filter by confidence threshold, draw bounding boxes, labels, etc.)

    # Display the processed frame with detections
    cv2.imshow('Real-time Object Detection', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break  # Exit the loop when 'q' key is pressed

cap.release()  # Release the camera
cv2.destroyAllWindows()  # Close the display window
# Out:
# 0: 640x640 1 person, 1 bowl, 3 beds, 234.6ms
# Speed: 5.0ms preprocess, 234.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 bowl, 2 beds, 34.2ms
# Speed: 4.0ms preprocess, 34.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 bowl, 1 bed, 31.1ms
# Speed: 4.0ms preprocess, 31.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 bowl, 3 beds, 33.0ms
# Speed: 5.0ms preprocess, 33.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 bowl, 2 beds, 33.0ms
# Speed: 3.5ms preprocess, 33.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 bowl, 2 beds, 34.5ms
# Speed: 4.5ms preprocess, 34.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 person, 1 bowl, 2 beds, 34.0ms
# ...

# %%
 ret, frame = cap.read()

# %%
ret
# Out:
# True

# %%
import os 
home = os.getcwd()
print(home)
# Out:
# C:\Users\admin\Desktop\college_ work\sih

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="LkeKgJL3JtbooBWvjEye")
project = rf.workspace("zealousmw").project("weapon_detection-0dyn4")
dataset = project.version(1).download("yolov8")
# Out:
# ...
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.134 is required but found version=8.0.188, to fix: `pip install ultralytics==8.0.134`
# ...
# Extracting Dataset Version Zip to weapon_detection-1 in yolov8:: 100%|███████████| 1003/1003 [00:00<00:00, 4981.34it/s]

# %%
# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=25 imgsz=640
# Out:
# New https://pypi.org/project/ultralytics/8.0.190 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.188  Python-3.11.4 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# ...

# %%
model = YOLO('yolov8n.pt')  # build from YAML and transfer weights

results = model.train(data="weapon_detection-1/data.yaml", epochs=50, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.0.190 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.188  Python-3.11.4 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3060, 12288MiB)
# ...

# %%
dataset.location
# Out:
# 'C:\\Users\\admin\\Desktop\\college_ work\\sih\\weapon_detection-1'
